# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('BankChurners.csv')

# %%
dataset = dataset.replace('Unknown', np.nan)

# %%
dataset['CLIENTNUM'] = [x + 90032 for x in list(range(len(dataset)))]

# %%
dataset.to_csv('BankChurners_v2.csv', index=False)

# %%
dataset.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      90032  Existing Customer            45      M                3
# 1      90033  Existing Customer            49      F                5
# 2      90034  Existing Customer            51      M                3
# 3      90035  Existing Customer            40      F                4
# 4      90036  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School            NaN  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
dataset = dataset.dropna()

# %%
dataset.shape
# Out:
# (7081, 23)

# %%
dataset.isnull()
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0          False           False         False   False            False
# 1          False           False         False   False            False
# 2          False           False         False   False            False
# 4          False           False         False   False            False
# 5          False           False         False   False            False
# ...          ...             ...           ...     ...              ...
# 10120      False           False         False   False            False
# 10121      False           False         False   False            False
# 10122      False           False         False   False            False
# 10124      False           False         False   False            False
# 10126      False           False         False   False            False
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# ...

# %%
import pandas as pd

# %%
bins=[25,30,40,50,60,70,80]
labels = ['20s','30s','40s','50s','60s','70s']
dataset["new"]=pd.cut(dataset['Customer_Age'],bins=bins,labels=labels,include_lowest=True,right=False)

# %%
dataset.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      90032  Existing Customer            45      M                3
# 1      90033  Existing Customer            49      F                5
# 2      90034  Existing Customer            51      M                3
# 4      90036  Existing Customer            40      M                3
# 5      90037  Existing Customer            44      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
# 5        Graduate        Married     $40K - $60K          Blue
#
#    Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...                  777          11914.0
# ...

# %%
#EDA

dataset["Attrition_Flag"].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    5968
# Attrited Customer    1113
# Name: count, dtype: int64

# %%
#Summary statistics

# median is much better when
# there are outliers

dataset.describe()
# Out:
#            CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count    7081.000000   7081.000000      7081.000000     7081.000000
# mean    95002.298122     46.347691         2.337805       35.981359
# std      2967.582990      8.041225         1.291649        8.002609
# min     90032.000000     26.000000         0.000000       13.000000
# 25%     92391.000000     41.000000         1.000000       31.000000
# 50%     94933.000000     46.000000         2.000000       36.000000
# 75%     97583.000000     52.000000         3.000000       40.000000
# max    100158.000000     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               7081.000000             7081.000000
# mean                   3.819376                2.342607
# std                    1.544444                0.995104
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...
